# %%
import matplotlib.pyplot as plt

x = [7, 8, 9, 10, 11, 12]
y = [0.1160198182866, 0.0402077203774371, 0.0119680113792242, 0.00714905809792854, 0.00212005482783116, 0.00206716950821854]

plt.scatter(x, y)
plt.title("Fidelity as function of layer depth, 54 qubits, A100 GPU")
plt.xlabel("Circuit layers")
plt.ylabel("Fidelity")
plt.show()

# %%
import numpy as np

yLog = np.log10(y)

plt.scatter(x, yLog)
plt.title("Log fidelity as function of layer depth, 54 qubits, A100 GPU")
plt.xlabel("Circuit layers")
plt.ylabel("Log10(Fidelity)")
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(14, 14)
plt.rc('legend',fontsize=16)
plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(figsize = (9, 9))
plt.title("Fidelity vs layer depth, 54 qubits, A100 GPU")
plt.xlabel("Circuit layers")
plt.ylabel("Log10(Fidelity)")

ax.scatter(x, yLog)

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(x, yLog)

line = slope*np.array(x)+intercept
ax.plot(x, line, 'k', label='y={:.2f}x+{:.2f}'.format(slope,intercept))
plt.legend()

fig.savefig('noisy_a100.png', dpi=100)

# %%
sse = 0
sst = 0
for i in range(len(yLog)):
    o = yLog[i]
    sst += o * o
    res = (o - (a + b * (i + 7)))
    sse += res * res

print("slope: ", b)
print("intercept: ", a)
print("R-squared: ", (1 - sse / sst))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       4     o = yLog[i]
#       5     sst += o * o
# ----> 6     res = (o - (a + b * (i + 7)))
#       7     sse += res * res
#       9 print("slope: ", b)
#
# NameError: name 'a' is not defined
